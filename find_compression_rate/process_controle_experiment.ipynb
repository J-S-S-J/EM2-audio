# %%
import pandas as pd

# %%
df = pd.read_csv("../experiment/control_experiment/data_typing/test4_001_2025-11-10_23-10-23_typing.csv", sep=",")

# %%
# Vi mangler at have trials hvor prime ikke er present og en mulughed for at sige "ingen prime tilstede"
df["accuracy"]
hit_rate = len(df[df["accuracy"] == True]) / len(df)
false_alarm_rate = len(df[df["accuracy"] == False]) / len(df)
false_alarm_rate
# Out:
# 0.875
