# %%
import pandas as pd

# %%
df = pd.read_csv("../experiment/control_experiment/data_detection/11_001_2025-11-11_13-51-32_detection.csv", sep=",")

# %%
# Vi mangler at have trials hvor prime ikke er present og en mulughed for at sige "ingen prime tilstede"
hit_rate = len(df[df["trial_outcome"] == "Hit"]) / len(df)
false_alarm_rate = len(df[df["trial_outcome"] == "False Alarm"]) / len(df)
